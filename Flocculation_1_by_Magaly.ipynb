# %% [markdown]
# <a href="https://colab.research.google.com/github/Magaly2022/CursoFazt/blob/master/Flocculation_1_by_Magaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib notebook
# %matplotlib inline

# %%
df=pd.read_excel(r"Data FLO First test.xlsx")
df.head(15)
# Out:
#                Yeast  % Flocculation                    Type
# 0   Non-flocculating       19.000000  Type 2 (nonflocculent)
# 1   Non-flocculating       18.500000  Type 2 (nonflocculent)
# 2   Non-flocculating       19.500000  Type 2 (nonflocculent)
# 3               L01D       78.694188     Type 1 (flocculent)
# 4               L01D       78.820239     Type 1 (flocculent)
# 5               L01D       78.753762     Type 1 (flocculent)
# 6               L02A       83.840441     Type 1 (flocculent)
# 7               L02A       83.275941     Type 1 (flocculent)
# 8               L02A       83.685965     Type 1 (flocculent)
# 9               L04A       71.042260     Type 1 (flocculent)
# 10              L04A       72.164874     Type 1 (flocculent)
# 11              L04A       72.178816     Type 1 (flocculent)
# 12              A04A       77.904429     Type 1 (flocculent)
# 13              A04A       77.578581     Type 1 (flocculent)
# ...

# %%
# Análisis de datos usando gráfico de violin en seaborn
my_colors = ["#9b59b6", "#3498db"] 
sns.set_palette( my_colors ) 
sns.violinplot(data=df, x='Yeast', y= '% Flocculation', hue = 'Type');
